# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/quick_commerce_data_raw.csv")

# %%
df
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID                        0
# Company                         0
# City                        52000
# Customer_Age                    0
# Order_Value                     0
# Delivery_Time_Min               0
# Distance_Km                     0
# Items_Count                 35000
# Product_Category                0
# Payment_Method                  0
# Customer_Rating             47000
# Discount_Applied                0
# Delivery_Partner_Rating    104137
# dtype: int64

# %%
df["City"].mode()
# Out:
# 0    Hyderabad
# Name: City, dtype: object

# %%
df["Items_Count"].mean()
# Out:
# np.float64(9.998317098445597)

# %%
df["City"].fillna("Hyderabad",inplace=True) #replace null with hydrabad
df["Items_Count"].fillna(9.99,inplace=True)
# Out:
# /tmp/ipykernel_2055/948498566.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["City"].fillna("Hyderabad",inplace=True) #replace null with hydrabad
# /tmp/ipykernel_2055/948498566.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df["Customer_Rating"].mean()
# Out:
# np.float64(3.0420720881427084)

# %%
df["Customer_Rating"].fillna(3.04,inplace=True)
# Out:
# /tmp/ipykernel_2055/722766888.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Customer_Rating"].fillna(3.04,inplace=True)

# %%
df["Delivery_Partner_Rating"].mean()
# Out:
# np.float64(3.749256526946642)

# %%
df["Delivery_Partner_Rating"].fillna(3.74,inplace=True)
# Out:
# /tmp/ipykernel_2055/2680548418.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Delivery_Partner_Rating"].fillna(3.74,inplace=True)

# %%
plt.figure(figsize=(14,6))
df.boxplot()
# Out:
# <Axes: >

# %%
df.drop(columns=("Order_ID"),inplace=True)

# %%
plt.figure(figsize=(14,6))
df.boxplot()
# Out:
# <Axes: >

# %%
filtered =df[df["Order_Value"]<2500]

# %%
plt.figure(figsize=(14,6))
filtered.boxplot()
# Out:
# <Axes: >

# %%
df.drop(columns=["Order_Value"], inplace=True)

# %%
plt.figure(figsize=(14,6))
df.boxplot()
# Out:
# <Axes: >
